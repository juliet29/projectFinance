# %%
import pandas as pd
import numpy as np
from data import * 
from inputs import *
from expenses import * 
from revenues import *

# %% [markdown]
# # Expenses

# %%
debt_service_exp = debt_service_df.loc["Total"]
corp_exp = corp_df.loc[("Total", "")]
op_exp = op_df.loc[("Total", "")]

# %%
summ_df = pd.DataFrame([corp_exp, op_exp, debt_service_exp, ], index=["Corporate Expenses", "Operations Expenses", "Debt Service"])
summ_df
# Out:
#                      Financial Close - July 2023  \
# Corporate Expenses                           0.0
# Operations Expenses                          0.0
# Debt Service                                 0.0
#
#                      Construction Year 1 - July 2024  \
# Corporate Expenses                         9602000.0
# Operations Expenses                              0.0
# Debt Service                                     0.0
#
#                      Commisioning and Construction Year 2 - July 2025  \
# Corporate Expenses                                          9842050.0
# Operations Expenses                                         9700000.0
# Debt Service                                               16800000.0
#
#                      July 2026 - Year 1  July 2027 - Year 2  \
# Corporate Expenses          10088101.25        1.034030e+07
# Operations Expenses          3000000.00        3.000000e+06
# Debt Service                50257935.00        4.599618e+07
#
#                      July 2028 - Year 3  July 2029 - Year 4  \
# Corporate Expenses         1.059881e+07        1.086378e+07
# Operations Expenses        3.000000e+06        3.000000e+06
# Debt Service               5.128977e+07        4.643717e+07
#
#                      July 2030 - Year 5  July 2031 - Year 6  \
# Corporate Expenses         1.113538e+07        1.141376e+07
# Operations Expenses        3.000000e+06        3.000000e+06
# Debt Service               5.139537e+07        4.744503e+07
#
#                      July 2032 - Year 7  ...  July 2056 - Year 31  \
# Corporate Expenses         1.169910e+07  ...         2.116047e+07
# Operations Expenses        3.000000e+06  ...         3.110000e+06
# Debt Service               5.093294e+07  ...         0.000000e+00
#
#                      July 2057 - Year 32  July 2058 - Year 33  \
# Corporate Expenses          2.168949e+07         2.223172e+07
# Operations Expenses         3.110000e+06         3.110000e+06
# Debt Service                0.000000e+00         0.000000e+00
#
#                      July 2059 - Year 34  July 2060 - Year 35  \
# Corporate Expenses          2.278752e+07         2.335720e+07
# Operations Expenses         3.110000e+06         3.110000e+06
# Debt Service                0.000000e+00         0.000000e+00
#
#                      July 2061 - Year 36  July 2062 - Year 37  \
# Corporate Expenses          2.394113e+07         2.453966e+07
# Operations Expenses         3.110000e+06         3.110000e+06
# Debt Service                0.000000e+00         0.000000e+00
#
#                      July 2063 - Year 38  July 2064 - Year 39  \
# Corporate Expenses          2.515315e+07         2.578198e+07
# Operations Expenses         3.110000e+06         3.110000e+06
# Debt Service                0.000000e+00         0.000000e+00
#
#                      July 2065 - Year 40
# Corporate Expenses          2.642653e+07
# Operations Expenses         3.110000e+06
# Debt Service                0.000000e+00
#
# [3 rows x 43 columns]

# %%
# summarize construction costs 
year_1 = const_df.iloc[const_df.index.get_level_values(0)=="Total", 2:14].sum(axis=1).values[0]

year_2 = const_df.iloc[const_df.index.get_level_values(0)=="Total", 14:].sum(axis=1).values[0]

by_fc = const_df.iloc[const_df.index.get_level_values(0)=="Total", 0:2].sum(axis=1).values[0]
year_1
# Out:
# 317503000.0

# %%
const_costs = len(summ_df.columns)*[0]
const_costs[0] = by_fc
const_costs[1] = year_1
const_costs[2] = year_2
const_exp = pd.DataFrame(const_costs, index=list(summ_df.columns), columns=["Construction Expenses"]).T

# %%
summary_df = pd.concat(objs=[const_exp, summ_df])

# %%
hipu_escrow_op = 22.5e6
hipu_escrow_fc = 7e6

hipu_escrow = [0]* len(year_nums)
hipu_escrow[0] = hipu_escrow_op
annual_escrow_dec = 0.05

for i in year_nums[0:-1]:
    hipu_escrow[i] = hipu_escrow[i-1]*(1-annual_escrow_dec)

hipu_escrow_full = [hipu_escrow_fc, hipu_escrow_fc, hipu_escrow_fc] + hipu_escrow

# %%
summary_df.loc["HIPU Escrow*"] = hipu_escrow_full

# %%
summary_df.loc["Total Expenses"] = summary_df.sum(axis=0)

# %% [markdown]
# # Net Income

# %%
summary_df.loc["Revenues"] = rev_df.loc["Total"].T # TODO expenses should be negative!

# %%
summary_df.loc["Net Income"] = summary_df.loc["Revenues"] - summary_df.loc["Total Expenses"]

# %%
summary_df
# Out:
#                        Financial Close - July 2023  \
# Construction Expenses                  104646000.0
# Corporate Expenses                             0.0
# Operations Expenses                            0.0
# Debt Service                                   0.0
# HIPU Escrow*                             7000000.0
# Total Expenses                         111646000.0
# Revenues                               550062792.0
# Net Income                             438416792.0
#
#                        Construction Year 1 - July 2024  \
# Construction Expenses                      317503000.0
# Corporate Expenses                           9602000.0
# Operations Expenses                                0.0
# Debt Service                                       0.0
# HIPU Escrow*                                 7000000.0
# Total Expenses                             334105000.0
# Revenues                                           0.0
# Net Income                                -334105000.0
#
#                        Commisioning and Construction Year 2 - July 2025  \
# Construction Expenses                                       317503000.0
# Corporate Expenses                                            9842050.0
# Operations Expenses                                           9700000.0
# Debt Service                                                 16800000.0
# HIPU Escrow*                                                  7000000.0
# Total Expenses                                              360845050.0
# Revenues                                                            0.0
# Net Income                                                 -360845050.0
#
#                        July 2026 - Year 1  July 2027 - Year 2  \
# Construction Expenses                0.00        0.000000e+00
# Corporate Expenses            10088101.25        1.034030e+07
# Operations Expenses            3000000.00        3.000000e+06
# Debt Service                  50257935.00        4.599618e+07
# HIPU Escrow*                  22500000.00        2.137500e+07
# Total Expenses                85846036.25        8.071148e+07
# Revenues                      80541120.00        8.456818e+07
# Net Income                    -5304916.25        3.856693e+06
#
#                        July 2028 - Year 3  July 2029 - Year 4  \
# Construction Expenses        0.000000e+00        0.000000e+00
# Corporate Expenses           1.059881e+07        1.086378e+07
# Operations Expenses          3.000000e+06        3.000000e+06
# Debt Service                 5.128977e+07        4.643717e+07
# HIPU Escrow*                 2.030625e+07        1.929094e+07
# Total Expenses               8.519483e+07        7.959189e+07
# Revenues                     8.879658e+07        9.323641e+07
# Net Income                   3.601753e+06        1.364453e+07
#
#                        July 2030 - Year 5  July 2031 - Year 6  \
# Construction Expenses        0.000000e+00        0.000000e+00
# Corporate Expenses           1.113538e+07        1.141376e+07
# Operations Expenses          3.000000e+06        3.000000e+06
# Debt Service                 5.139537e+07        4.744503e+07
# HIPU Escrow*                 1.832639e+07        1.741007e+07
# Total Expenses               8.385713e+07        7.926886e+07
# Revenues                     9.789823e+07        1.027931e+08
# Net Income                   1.404110e+07        2.352428e+07
#
#                        July 2032 - Year 7  ...  July 2056 - Year 31  \
# Construction Expenses        0.000000e+00  ...         0.000000e+00
# Corporate Expenses           1.169910e+07  ...         2.116047e+07
# Operations Expenses          3.000000e+06  ...         3.110000e+06
# Debt Service                 5.093294e+07  ...         0.000000e+00
# HIPU Escrow*                 1.653957e+07  ...         4.829372e+06
# Total Expenses               8.217162e+07  ...         2.909985e+07
# Revenues                     1.079328e+08  ...         3.480941e+08
# Net Income                   2.576119e+07  ...         3.189942e+08
#
#                        July 2057 - Year 32  July 2058 - Year 33  \
# Construction Expenses         0.000000e+00         0.000000e+00
# Corporate Expenses            2.168949e+07         2.223172e+07
# Operations Expenses           3.110000e+06         3.110000e+06
# Debt Service                  0.000000e+00         0.000000e+00
# HIPU Escrow*                  4.587904e+06         4.358508e+06
# Total Expenses                2.938739e+07         2.970023e+07
# Revenues                      3.654988e+08         3.837737e+08
# Net Income                    3.361114e+08         3.540735e+08
#
#                        July 2059 - Year 34  July 2060 - Year 35  \
# Construction Expenses         0.000000e+00         0.000000e+00
# Corporate Expenses            2.278752e+07         2.335720e+07
# Operations Expenses           3.110000e+06         3.110000e+06
# Debt Service                  0.000000e+00         0.000000e+00
# HIPU Escrow*                  4.140583e+06         3.933554e+06
# Total Expenses                3.003810e+07         3.040076e+07
# Revenues                      4.029624e+08         4.231105e+08
# Net Income                    3.729243e+08         3.927098e+08
#
#                        July 2061 - Year 36  July 2062 - Year 37  \
# Construction Expenses         0.000000e+00         0.000000e+00
# Corporate Expenses            2.394113e+07         2.453966e+07
# Operations Expenses           3.110000e+06         3.110000e+06
# Debt Service                  0.000000e+00         0.000000e+00
# HIPU Escrow*                  3.736876e+06         3.550032e+06
# Total Expenses                3.078801e+07         3.119969e+07
# Revenues                      4.442661e+08         4.664794e+08
# Net Income                    4.134780e+08         4.352797e+08
#
#                        July 2063 - Year 38  July 2064 - Year 39  \
# Construction Expenses         0.000000e+00         0.000000e+00
# Corporate Expenses            2.515315e+07         2.578198e+07
# Operations Expenses           3.110000e+06         3.110000e+06
# Debt Service                  0.000000e+00         0.000000e+00
# HIPU Escrow*                  3.372531e+06         3.203904e+06
# Total Expenses                3.163568e+07         3.209589e+07
# Revenues                      4.898033e+08         5.142935e+08
# Net Income                    4.581676e+08         4.821976e+08
#
#                        July 2065 - Year 40
# Construction Expenses         0.000000e+00
# Corporate Expenses            2.642653e+07
# Operations Expenses           3.110000e+06
# Debt Service                  0.000000e+00
# HIPU Escrow*                  3.043709e+06
# Total Expenses                3.258024e+07
# Revenues                      5.400082e+08
# Net Income                    5.074279e+08
#
# [8 rows x 43 columns]

# %% [markdown]
# # Taxes

# %%
# corporate taxes => 30% of net income
summary_df.loc["Corporate Tax Payable"] = summary_df.loc["Net Income"]*0.3

# %%
summary_df.iloc[-1, 0:4] = 0

# %%
summary_df
# Out:
#                        Financial Close - July 2023  \
# Construction Expenses                  104646000.0
# Corporate Expenses                             0.0
# Operations Expenses                            0.0
# Debt Service                                   0.0
# HIPU Escrow*                             7000000.0
# Total Expenses                         111646000.0
# Revenues                               550062792.0
# Net Income                             438416792.0
# Corporate Tax Payable                          0.0
#
#                        Construction Year 1 - July 2024  \
# Construction Expenses                      317503000.0
# Corporate Expenses                           9602000.0
# Operations Expenses                                0.0
# Debt Service                                       0.0
# HIPU Escrow*                                 7000000.0
# Total Expenses                             334105000.0
# Revenues                                           0.0
# Net Income                                -334105000.0
# Corporate Tax Payable                              0.0
#
#                        Commisioning and Construction Year 2 - July 2025  \
# Construction Expenses                                       317503000.0
# Corporate Expenses                                            9842050.0
# Operations Expenses                                           9700000.0
# Debt Service                                                 16800000.0
# HIPU Escrow*                                                  7000000.0
# Total Expenses                                              360845050.0
# Revenues                                                            0.0
# Net Income                                                 -360845050.0
# Corporate Tax Payable                                               0.0
#
#                        July 2026 - Year 1  July 2027 - Year 2  \
# Construction Expenses                0.00        0.000000e+00
# Corporate Expenses            10088101.25        1.034030e+07
# Operations Expenses            3000000.00        3.000000e+06
# Debt Service                  50257935.00        4.599618e+07
# HIPU Escrow*                  22500000.00        2.137500e+07
# Total Expenses                85846036.25        8.071148e+07
# Revenues                      80541120.00        8.456818e+07
# Net Income                    -5304916.25        3.856693e+06
# Corporate Tax Payable                0.00        1.157008e+06
#
#                        July 2028 - Year 3  July 2029 - Year 4  \
# Construction Expenses        0.000000e+00        0.000000e+00
# Corporate Expenses           1.059881e+07        1.086378e+07
# Operations Expenses          3.000000e+06        3.000000e+06
# Debt Service                 5.128977e+07        4.643717e+07
# HIPU Escrow*                 2.030625e+07        1.929094e+07
# Total Expenses               8.519483e+07        7.959189e+07
# Revenues                     8.879658e+07        9.323641e+07
# Net Income                   3.601753e+06        1.364453e+07
# Corporate Tax Payable        1.080526e+06        4.093358e+06
#
#                        July 2030 - Year 5  July 2031 - Year 6  \
# Construction Expenses        0.000000e+00        0.000000e+00
# Corporate Expenses           1.113538e+07        1.141376e+07
# Operations Expenses          3.000000e+06        3.000000e+06
# Debt Service                 5.139537e+07        4.744503e+07
# HIPU Escrow*                 1.832639e+07        1.741007e+07
# Total Expenses               8.385713e+07        7.926886e+07
# Revenues                     9.789823e+07        1.027931e+08
# Net Income                   1.404110e+07        2.352428e+07
# Corporate Tax Payable        4.212331e+06        7.057285e+06
#
#                        July 2032 - Year 7  ...  July 2056 - Year 31  \
# Construction Expenses        0.000000e+00  ...         0.000000e+00
# Corporate Expenses           1.169910e+07  ...         2.116047e+07
# Operations Expenses          3.000000e+06  ...         3.110000e+06
# Debt Service                 5.093294e+07  ...         0.000000e+00
# HIPU Escrow*                 1.653957e+07  ...         4.829372e+06
# Total Expenses               8.217162e+07  ...         2.909985e+07
# Revenues                     1.079328e+08  ...         3.480941e+08
# Net Income                   2.576119e+07  ...         3.189942e+08
# Corporate Tax Payable        7.728356e+06  ...         9.569827e+07
#
#                        July 2057 - Year 32  July 2058 - Year 33  \
# Construction Expenses         0.000000e+00         0.000000e+00
# Corporate Expenses            2.168949e+07         2.223172e+07
# Operations Expenses           3.110000e+06         3.110000e+06
# Debt Service                  0.000000e+00         0.000000e+00
# HIPU Escrow*                  4.587904e+06         4.358508e+06
# Total Expenses                2.938739e+07         2.970023e+07
# Revenues                      3.654988e+08         3.837737e+08
# Net Income                    3.361114e+08         3.540735e+08
# Corporate Tax Payable         1.008334e+08         1.062220e+08
#
#                        July 2059 - Year 34  July 2060 - Year 35  \
# Construction Expenses         0.000000e+00         0.000000e+00
# Corporate Expenses            2.278752e+07         2.335720e+07
# Operations Expenses           3.110000e+06         3.110000e+06
# Debt Service                  0.000000e+00         0.000000e+00
# HIPU Escrow*                  4.140583e+06         3.933554e+06
# Total Expenses                3.003810e+07         3.040076e+07
# Revenues                      4.029624e+08         4.231105e+08
# Net Income                    3.729243e+08         3.927098e+08
# Corporate Tax Payable         1.118773e+08         1.178129e+08
#
#                        July 2061 - Year 36  July 2062 - Year 37  \
# Construction Expenses         0.000000e+00         0.000000e+00
# Corporate Expenses            2.394113e+07         2.453966e+07
# Operations Expenses           3.110000e+06         3.110000e+06
# Debt Service                  0.000000e+00         0.000000e+00
# HIPU Escrow*                  3.736876e+06         3.550032e+06
# Total Expenses                3.078801e+07         3.119969e+07
# Revenues                      4.442661e+08         4.664794e+08
# Net Income                    4.134780e+08         4.352797e+08
# Corporate Tax Payable         1.240434e+08         1.305839e+08
#
#                        July 2063 - Year 38  July 2064 - Year 39  \
# Construction Expenses         0.000000e+00         0.000000e+00
# Corporate Expenses            2.515315e+07         2.578198e+07
# Operations Expenses           3.110000e+06         3.110000e+06
# Debt Service                  0.000000e+00         0.000000e+00
# HIPU Escrow*                  3.372531e+06         3.203904e+06
# Total Expenses                3.163568e+07         3.209589e+07
# Revenues                      4.898033e+08         5.142935e+08
# Net Income                    4.581676e+08         4.821976e+08
# Corporate Tax Payable         1.374503e+08         1.446593e+08
#
#                        July 2065 - Year 40
# Construction Expenses         0.000000e+00
# Corporate Expenses            2.642653e+07
# Operations Expenses           3.110000e+06
# Debt Service                  0.000000e+00
# HIPU Escrow*                  3.043709e+06
# Total Expenses                3.258024e+07
# Revenues                      5.400082e+08
# Net Income                    5.074279e+08
# Corporate Tax Payable         1.522284e+08
#
# [9 rows x 43 columns]

# %%
summary_df.loc["After Tax Income"] = summary_df.loc["Net Income"] - summary_df.loc["Corporate Tax Payable"]

# %%
summary_df
# Out:
#                        Financial Close - July 2023  \
# Construction Expenses                  104646000.0
# Corporate Expenses                             0.0
# Operations Expenses                            0.0
# Debt Service                                   0.0
# HIPU Escrow*                             7000000.0
# Total Expenses                         111646000.0
# Revenues                               550062792.0
# Net Income                             438416792.0
# Corporate Tax Payable                          0.0
# After Tax Income                       438416792.0
#
#                        Construction Year 1 - July 2024  \
# Construction Expenses                      317503000.0
# Corporate Expenses                           9602000.0
# Operations Expenses                                0.0
# Debt Service                                       0.0
# HIPU Escrow*                                 7000000.0
# Total Expenses                             334105000.0
# Revenues                                           0.0
# Net Income                                -334105000.0
# Corporate Tax Payable                              0.0
# After Tax Income                          -334105000.0
#
#                        Commisioning and Construction Year 2 - July 2025  \
# Construction Expenses                                       317503000.0
# Corporate Expenses                                            9842050.0
# Operations Expenses                                           9700000.0
# Debt Service                                                 16800000.0
# HIPU Escrow*                                                  7000000.0
# Total Expenses                                              360845050.0
# Revenues                                                            0.0
# Net Income                                                 -360845050.0
# Corporate Tax Payable                                               0.0
# After Tax Income                                           -360845050.0
#
#                        July 2026 - Year 1  July 2027 - Year 2  \
# Construction Expenses                0.00        0.000000e+00
# Corporate Expenses            10088101.25        1.034030e+07
# Operations Expenses            3000000.00        3.000000e+06
# Debt Service                  50257935.00        4.599618e+07
# HIPU Escrow*                  22500000.00        2.137500e+07
# Total Expenses                85846036.25        8.071148e+07
# Revenues                      80541120.00        8.456818e+07
# Net Income                    -5304916.25        3.856693e+06
# Corporate Tax Payable                0.00        1.157008e+06
# After Tax Income              -5304916.25        2.699685e+06
#
#                        July 2028 - Year 3  July 2029 - Year 4  \
# Construction Expenses        0.000000e+00        0.000000e+00
# Corporate Expenses           1.059881e+07        1.086378e+07
# Operations Expenses          3.000000e+06        3.000000e+06
# Debt Service                 5.128977e+07        4.643717e+07
# HIPU Escrow*                 2.030625e+07        1.929094e+07
# Total Expenses               8.519483e+07        7.959189e+07
# Revenues                     8.879658e+07        9.323641e+07
# Net Income                   3.601753e+06        1.364453e+07
# Corporate Tax Payable        1.080526e+06        4.093358e+06
# After Tax Income             2.521227e+06        9.551168e+06
#
#                        July 2030 - Year 5  July 2031 - Year 6  \
# Construction Expenses        0.000000e+00        0.000000e+00
# Corporate Expenses           1.113538e+07        1.141376e+07
# Operations Expenses          3.000000e+06        3.000000e+06
# Debt Service                 5.139537e+07        4.744503e+07
# HIPU Escrow*                 1.832639e+07        1.741007e+07
# Total Expenses               8.385713e+07        7.926886e+07
# Revenues                     9.789823e+07        1.027931e+08
# Net Income                   1.404110e+07        2.352428e+07
# Corporate Tax Payable        4.212331e+06        7.057285e+06
# After Tax Income             9.828771e+06        1.646700e+07
#
#                        July 2032 - Year 7  ...  July 2056 - Year 31  \
# Construction Expenses        0.000000e+00  ...         0.000000e+00
# Corporate Expenses           1.169910e+07  ...         2.116047e+07
# Operations Expenses          3.000000e+06  ...         3.110000e+06
# Debt Service                 5.093294e+07  ...         0.000000e+00
# HIPU Escrow*                 1.653957e+07  ...         4.829372e+06
# Total Expenses               8.217162e+07  ...         2.909985e+07
# Revenues                     1.079328e+08  ...         3.480941e+08
# Net Income                   2.576119e+07  ...         3.189942e+08
# Corporate Tax Payable        7.728356e+06  ...         9.569827e+07
# After Tax Income             1.803283e+07  ...         2.232960e+08
#
#                        July 2057 - Year 32  July 2058 - Year 33  \
# Construction Expenses         0.000000e+00         0.000000e+00
# Corporate Expenses            2.168949e+07         2.223172e+07
# Operations Expenses           3.110000e+06         3.110000e+06
# Debt Service                  0.000000e+00         0.000000e+00
# HIPU Escrow*                  4.587904e+06         4.358508e+06
# Total Expenses                2.938739e+07         2.970023e+07
# Revenues                      3.654988e+08         3.837737e+08
# Net Income                    3.361114e+08         3.540735e+08
# Corporate Tax Payable         1.008334e+08         1.062220e+08
# After Tax Income              2.352780e+08         2.478514e+08
#
#                        July 2059 - Year 34  July 2060 - Year 35  \
# Construction Expenses         0.000000e+00         0.000000e+00
# Corporate Expenses            2.278752e+07         2.335720e+07
# Operations Expenses           3.110000e+06         3.110000e+06
# Debt Service                  0.000000e+00         0.000000e+00
# HIPU Escrow*                  4.140583e+06         3.933554e+06
# Total Expenses                3.003810e+07         3.040076e+07
# Revenues                      4.029624e+08         4.231105e+08
# Net Income                    3.729243e+08         3.927098e+08
# Corporate Tax Payable         1.118773e+08         1.178129e+08
# After Tax Income              2.610470e+08         2.748968e+08
#
#                        July 2061 - Year 36  July 2062 - Year 37  \
# Construction Expenses         0.000000e+00         0.000000e+00
# Corporate Expenses            2.394113e+07         2.453966e+07
# Operations Expenses           3.110000e+06         3.110000e+06
# Debt Service                  0.000000e+00         0.000000e+00
# HIPU Escrow*                  3.736876e+06         3.550032e+06
# Total Expenses                3.078801e+07         3.119969e+07
# Revenues                      4.442661e+08         4.664794e+08
# Net Income                    4.134780e+08         4.352797e+08
# Corporate Tax Payable         1.240434e+08         1.305839e+08
# After Tax Income              2.894346e+08         3.046958e+08
#
#                        July 2063 - Year 38  July 2064 - Year 39  \
# Construction Expenses         0.000000e+00         0.000000e+00
# Corporate Expenses            2.515315e+07         2.578198e+07
# Operations Expenses           3.110000e+06         3.110000e+06
# Debt Service                  0.000000e+00         0.000000e+00
# HIPU Escrow*                  3.372531e+06         3.203904e+06
# Total Expenses                3.163568e+07         3.209589e+07
# Revenues                      4.898033e+08         5.142935e+08
# Net Income                    4.581676e+08         4.821976e+08
# Corporate Tax Payable         1.374503e+08         1.446593e+08
# After Tax Income              3.207173e+08         3.375383e+08
#
#                        July 2065 - Year 40
# Construction Expenses         0.000000e+00
# Corporate Expenses            2.642653e+07
# Operations Expenses           3.110000e+06
# Debt Service                  0.000000e+00
# HIPU Escrow*                  3.043709e+06
# Total Expenses                3.258024e+07
# Revenues                      5.400082e+08
# Net Income                    5.074279e+08
# Corporate Tax Payable         1.522284e+08
# After Tax Income              3.551995e+08
#
# [10 rows x 43 columns]
