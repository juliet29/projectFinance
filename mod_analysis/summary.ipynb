# %%
import pandas as pd
import numpy as np
from model import *

# %% [markdown]
# ### base case

# %%
# base case
a = FinancialModel()
a.run_base_case()
print(a.roe) # 3.76
# Out:
# 4.156306486994646

# %%
k = [v for v in a.corporate_costs.values()]
k
# Out:
# [{'Corporate Resources': [1900000.0]},
#  {'Engineering': [220000.0],
#   'Legal': [315000.0],
#   'Accounting': [180000.0],
#   'Community Relations': [80000.0],
#   'Industry Relations': [20000.0],
#   'Misc.': [50000.0]},
#  {'Station Power Service': [285000.0],
#   'Utilities': [65000.0],
#   'Rent': [82000.0],
#   'Telecommunications': [50000.0],
#   'Travel/Office': [260000.0],
#   'Misc.': [200000.0],
#   'Contingency': [120000.0]},
#  {'Insurance': [2500000.0],
#   'Property Taxes': [2550000.0],
#   'Cable Easment': [700000.0],
#   'Contribution to Stanford Global Project Center': [25000.0]}]

# %%
total_const_expense = a.construction_expense_df.loc["Total", :].sum(axis=1)/1e6
a.format_df(a.construction_expense_df)
# Out:
#                                                                                        Pre-Financial Close  \
# Pre-Financial Close Expenses                       Wetland Construction Permit                         3.0
#                                                    State Environmental Monitoring Fee                  0.8
# Financial Close Expenses                           Land Acquisition                                    0.0
#                                                    Development Expenses                                0.0
#                                                    Development Fees                                    0.0
#                                                    Closing Costs                                       0.0
#                                                    Contingency Fees                                    0.0
# Construction Period Even Split Monthly Expenses    Interest and Fees                                   0.0
# ...

# %%
a.format_df(a.corporate_expense_df, 4)
# Out:
#                                                                    Financial Close - July 2023  \
# General            Corporate Resources                                                     0.0
# Outside Reources   Engineering                                                             0.0
#                    Legal                                                                   0.0
#                    Accounting                                                              0.0
#                    Community Relations                                                     0.0
#                    Industry Relations                                                      0.0
#                    Misc.                                                                   0.0
# Overhead           Station Power Service                                                   0.0
#                    Utilities                                                               0.0
# ...

# %%
a.format_df(a.operating_expense_df, 4)
# Out:
#                                                                         Financial Close - July 2023  \
# Commisioning Fees                   ABSCO Interconnection Fee                                   0.0
#                                     ABSCO Network Upgrades                                      0.0
#                                     HIPU Interconnection Fee                                    0.0
# Operating Fees to External Entities Quarterly MaintCo Maintennance Fee                          0.0
#                                     Annual Fisheries Mitigation Permit                          0.0
#                                     Monthly HIPU Interconection Fee                             0.0
# Total                                                                                           0.0
#
#                                                                         Construction Year 1 - July 2024  \
# ...

# %%
a.format_df(a.exp_df)
# Out:
#               Financial Close - July 2023  Construction Year 1 - July 2024  \
# Construction                       104.65                            317.5
# Operating                            0.00                              0.0
# Corporate                            0.00                              9.6
# Total                              104.65                            327.1
#
#               Commisioning and Construction Year 2 - July 2025  \
# Construction                                            317.50
# Operating                                                 9.70
# Corporate                                                 9.84
# Total                                                   337.05
#
#               July 2026 - Year 1  July 2027 - Year 2  July 2028 - Year 3  \
# Construction                0.00                0.00                0.00
# Operating                   4.21                4.21                4.21
# ...

# %%
a.df_out_format
# Out:
#                                 Financial Close - July 2023  \
# Revenue                                                0.00
# Capital and Operating Expenses                      -104.65
# Taxable Debt Service Expenses                         -0.00
# Total Expenses                                      -104.65
# EBITDA                                              -104.65
# Depreciation Value                                   -35.50
# EBIT                                                -140.15
# Corporate Tax Due                                     -0.00
# Net Income                                          -140.15
# Loan Repayments Due                                   -0.00
# HIPU Escrow Account                                   -7.00
# Loan Income                                          550.06
# Equity Income                                        235.74
# Cash Flow                                            438.42
# Cumulative Cash Flow                                 438.42
#
# ...
